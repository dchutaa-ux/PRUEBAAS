# %%
import numpy.polynomial as P

# %%
p=P.Polynomial([1,2,3])
print(p)
r = P.Polynomial([-1,0,0,1])
print(r)
print(r.degree())
print(r.coef)
print(r.roots())
q = P.Polynomial.fromroots([-1,1])
print(q)
# Out:
# 1.0 + 2.0 x + 3.0 x**2
# -1.0 + 0.0 x + 0.0 x**2 + 1.0 x**3
# 3
# [-1.  0.  0.  1.]
# [-0.5-0.8660254j -0.5+0.8660254j  1. +0.j       ]
# -1.0 + 0.0 x + 1.0 x**2
